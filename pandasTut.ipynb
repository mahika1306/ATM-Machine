# %% [markdown]
# <a href="https://colab.research.google.com/github/mahika1306/ATM-Machine/blob/main/pandasTut.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

# %%
#Creating a DataFrame
df=pd.DataFrame({
    'ID':[1,2,3,4,5,6,7,8],
    'Age':[25,36,17,8,3,12,18,24],
    'Gender':['male','female','not stated','male','male','female','not stated','female']
})

# %%
df
# Out:
#    ID  Age      Gender
# 0   1   25        male
# 1   2   36      female
# 2   3   17  not stated
# 3   4    8        male
# 4   5    3        male
# 5   6   12      female
# 6   7   18  not stated
# 7   8   24      female

# %%
#common functions
df.head(5)
# Out:
#    ID  Age      Gender
# 0   1   25        male
# 1   2   36      female
# 2   3   17  not stated
# 3   4    8        male
# 4   5    3        male

# %%
df.tail(2)#prints last rows
# Out:
#    ID  Age      Gender
# 6   7   18  not stated
# 7   8   24      female

# %%
df.info() #gives general info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      8 non-null      int64
#  1   Age     8 non-null      int64
#  2   Gender  8 non-null      object
# dtypes: int64(2), object(1)
# memory usage: 320.0+ bytes

# %%
df.describe() #gives general stats
# Out:
#             ID        Age
# count  8.00000   8.000000
# mean   4.50000  17.875000
# std    2.44949  10.494046
# min    1.00000   3.000000
# 25%    2.75000  11.000000
# 50%    4.50000  17.500000
# 75%    6.25000  24.250000
# max    8.00000  36.000000

# %%
df
# Out:
#    ID  Age      Gender
# 0   1   25        male
# 1   2   36      female
# 2   3   17  not stated
# 3   4    8        male
# 4   5    3        male
# 5   6   12      female
# 6   7   18  not stated
# 7   8   24      female

# %%
df['Gender']
# Out:
# 0          male
# 1        female
# 2    not stated
# 3          male
# 4          male
# 5        female
# 6    not stated
# 7        female
# Name: Gender, dtype: object

# %%
df[['Gender']]
# Out:
#        Gender
# 0        male
# 1      female
# 2  not stated
# 3        male
# 4        male
# 5      female
# 6  not stated
# 7      female

# %%
type(df['Gender'])
# Out:
# pandas.core.series.Series

# %%
df['Gender'].value_counts()
# Out:
# male          3
# female        3
# not stated    2
# Name: Gender, dtype: int64

# %%
df.loc[3,'Gender']
# Out:
# 'male'

# %%
df.iloc[3,2]
# Out:
# 'male'
